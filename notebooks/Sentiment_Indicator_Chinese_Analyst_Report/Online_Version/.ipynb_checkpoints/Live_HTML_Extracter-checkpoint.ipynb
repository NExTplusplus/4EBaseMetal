# %%
from newspaper import Article
from newspaper import fulltext
import time
import datetime
import pickle
import pandas as pd
import sqlalchemy as sq
from bs4 import BeautifulSoup
from inscriptis import get_text

# %%
engine = sq.create_engine("mysql+pymysql://root:next++4e@localhost/Alternative_DB?host=localhost?port=3306")
conn = engine.connect()

# %%
website_link_lst =[]
website_link_lst.append('http://www.dlqh.com/page-1-4.php')
website_link_lst.append('http://www.cnhtqh.com.cn/list/664/1.shtml?id=jsqh')
website_link_lst.append('http://www.bocifco.com/Category_86/Index.aspx')
website_link_lst.append('http://www.xzfutures.com/deeconomic.html')
website_link_lst.append('http://www.xzfutures.com/deeconomic_cid_119.html')
website_link_lst.append('https://www.mfc.com.cn/research.html')
website_link_lst.append('http://www.gzjkqh.com/czjy/list_36.aspx')
website_link_lst.append('http://www.shqhgs.com/lists/Dailystudy/p/1.html')
website_link_lst.append('http://www.zcqh.com/zcyj_z.php?name=%E6%AF%8F%E6%97%A5%E6%97%A9%E6%8A%A5&page=1')
website_link_lst.append('http://www.tqfutures.com/zpts/list_14.html')
website_link_lst.append('http://www.shcifco.com/html/yanjiuzhongxin/shishikuaixun/weipantishi/')
website_link_lst.append('https://www.dyqh.info/research/researchreport/8/2?tag=1')
website_link_lst.append('http://www.xzfutures.com/deeconomic_cid_107.html')
website_link_lst.append('https://www.rdqh.com/content/index/115?page=1')
website_link_lst.append('http://www.jtqh.cn/yfzx_1.asp?fl=1&lm=2&pz=%CD%AD')
website_link_lst.append('http://www.sdfutures.com.cn/a/sdyanjiu/jinshu/ribao/list_151_1.html')
website_link_lst.append('http://www.guosenqh.com.cn/main/yjzx/zp/zp_metal/index.shtml')
website_link_lst.append('http://www.gtaxqh.com/html/RESEARCH_SERVICES/pzbg/ysjgjs/')
website_link_lst.append('http://www.cnhtqh.com.cn/list/654/1.shtml?id=cjzbc')
website_link_lst.append('http://www.shcifco.com/html/yanjiuzhongxin/shishikuaixun/qishizaobanche/')
website_link_lst.append('https://www.dyqh.info/research/researchreport/6/0?tag=1')
website_link_lst.append('http://www.xzfutures.com/deeconomic_page_1.html?cid=114')
website_link_lst.append('http://www.gzf2010.com.cn/ResearchCenter.aspx?c=220102&page=1')
website_link_lst.append('http://www.jxgsqh.com/News_list.aspx?Sort_Id=634&Mid=629')
website_link_lst.append('http://www.hongyuanqh.com/hyqhnew/hyyj/more_index.jsp?1=1&oneMenuId=000200010015&twoMenuId=0002000100150001&threeMenuid=00020001001500010002&classId=000200010015000100020004&productid=100')
website_link_lst.append('http://www.hhqh.com.cn/?pcyear=10-24-13')
website_link_lst.append('http://www.bhfcc.com/research_page_1.html?pid=88')
website_link_lst.append('https://www.thanf.com/list-83.html')
website_link_lst.append('http://www.bocifco.com/Category_28/Index.aspx')
website_link_lst.append('http://www.ftol.com.cn/main/yfzx/rcbg/rcbg/zaoping/index.shtml')
website_link_lst.append('https://www.cnzsqh.com/cms/column/index?id=116')
website_link_lst.append('http://www.fnqh.com.cn/content/index/85')
website_link_lst.append('http://www.xzfutures.com/deeconomic_cid_106.html')
website_link_lst.append('http://www.gzf2010.com.cn/ResearchCenter.aspx?c=220101')
website_link_lst.append('http://www.hlqh.com/article_cat.php?id=96&t_id=96')
website_link_lst.append('https://www.btqh.com/index.php?m=content&c=index&a=lists&catid=56')
website_link_lst.append('http://www.szjhqh.com/index.php?s=news&c=category&id=10')
website_link_lst.append('https://www.htfc.com/main/yjzx/yjbg/index.shtml')
website_link_lst.append('http://www.guosenqh.com.cn/main/yjzx/rp/rp_metal/index.shtml')
website_link_lst.append('http://www.gtaxqh.com/html/RESEARCH_SERVICES/zhlcb/mrsp/')
website_link_lst.append('http://www.shcifco.com/html/yanjiuzhongxin/shishikuaixun/panzhongshidian/')

# %%
class html_extracter:
    def __init__(self,conn,build_db_content = False):
        
        self.conn_extracter = conn
        if build_db_content:
            self.build_content_db()
    
    def build_content_db(self):
        # Function: Set up a database to store accuracy with the following setting. 
        # Note that: All functions in this class will follow this setting, pls set up ur database accordingly to avoid error
        self.conn_extracter.execute('CREATE TABLE `Alternative_DB`.`content`(`url` VARCHAR(750) NOT NULL,`id` INT NOT NULL AUTO_INCREMENT,`date` DATETIME NOT NULL,`company` VARCHAR(30) NULL,`type` VARCHAR(45) NULL,`title` TINYTEXT NULL,`content` MEDIUMTEXT NULL,PRIMARY KEY (`url`),KEY(`id`));')
    
    def extract(self,df_news,date):
        # Function: This function will extract content from html
        # Inputs: df_news is the crawled report dataframe gotten from live crawler, date is today date
        # function_content is the fucntion to extract content from specific html style
        
        
        # Check whether table in database has been created 
        result = self.conn_extracter.execute("SHOW TABLES LIKE 'content';")
        
        if  not result.first():
            raise Exception('Database not exist, please use build_content_db function')
        
        # Record data that has problems when we try to extract
        
        problem={}
        for news_id,title,type1, name,url,html in zip(df_news['id'],df_news['title'],df_news['type'],df_news['company'],df_news['url'],df_news['html']):
            try:
                new_input = {}
                new_input['date'] = [date]
                new_input['company'] = [name]
                new_input['type'] = [type1]
                new_input['title'] = [title]
                new_input['url'] = [url]
                
                function_content = self.choose_func(url)
                
                #Extract Content
                text = function_content(html)
                if len(text)==0:
                    raise Exception('Empty')
                else:
                    new_input['Content'] = [text]
            
            
                df_input = pd.DataFrame(new_input)
                df_input.to_sql(name='content', con=self.conn_extracter, if_exists='append',index=False)
        
            except Exception as e:
                # If still have problem, record it
                print('Problem found',e)
                if str(e) in problem:
                    problem[str(e)].append(news_id)
                else:
                    problem[str(e)] = [news_id]

                
                continue 
        
        print ('Completed')
        return problem 
    
    def choose_func(self,url):
        # Function: this function will return a suitable function that can extract html accordingly
        fulltext_lst = ['gtaxqh','htfc','szjhqh','btqh','hlqh','fnqh','cnzsqh','ftol','dlqh','cnhtqh','mfc','gzjkqh','shqhgs','zcqh','tqfutures','shcifco','rdqh','jtqh','hhqh','bhfcc']
        keyword = url.split('.')[1]
        if keyword in fulltext_lst:
            func = lambda x: fulltext(x, 'zh')
        elif 'bocifco' in keyword:
            func = lambda x: BeautifulSoup(x).find("div", {"class": "contArticle_text"}).text
        elif 'xzfutures' in keyword:
            func = lambda x: BeautifulSoup(x).find("div", {"class": "aboutfont"}).text
        elif 'dyqh' in keyword:
            func = lambda x: BeautifulSoup(x).find("div", {"class": "news-list news-info"}).find("div", {"class": "cont"}).text
        elif 'sdfutures' in keyword:
            func = lambda x: BeautifulSoup(x).find("div", {"class": "mainContent"}).text
        elif 'guosenqh' in keyword:
            func = lambda x: BeautifulSoup(x).find("div", {"class": "jp_yyb_box"}).text
        elif 'gtaxqh' in keyword:
            func = lambda x: BeautifulSoup(x).find("div", {"class": "right_service0"}).text
        elif 'gzf2010' in keyword :
            func = lambda x: BeautifulSoup(x).find("div", {"class": "r right right_all"}).text
        elif 'jxgsqh' in keyword:
            func = lambda x: BeautifulSoup(x).find("li", {"class": "ny_li2"}).text
        elif 'hongyuanqh' in keyword:
            func = lambda x: BeautifulSoup(x).find("div", {"class": "about_text1"}).text
        elif 'thanf' in keyword:
            func = lambda x: BeautifulSoup(x).find("p", {"class": "text-justify"}).text
        else:
            raise Exception('Website not in choose_func please add it accordingly')
        return func

# %%
extracter = html_extracter(conn)

# %%
df_crawl = pd.read_sql('Select * from html',conn)

# %%
extracter.extract(df_crawl,'2019-05-28')
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.524 seconds.
# Prefix dict has been built succesfully.
# Problem found (pymysql.err.IntegrityError) (1062, "Duplicate entry 'http://www.gtaxqh.com/html/2017/mrsp_0831/13106.html' for key 'PRIMARY'")
# [SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]
# [parameters: {'date': '2019-05-28', 'company': '国投安信', 'type': 'After Market', 'title': '国投安信期货每日收评\n2017-08-31', 'url': 'http://www.gtaxqh.com/html/2017/mrsp_0831/13106.html', 'Content': '当前位置：首页>研究服务>综合类晨报>每日收评\n\n国投安信期货每日收评\n\n来源： 发布时间：2017-08-31\n\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1233 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。'}]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# Problem found (pymysql.err.IntegrityError) (1062, "Duplicate entry 'http://www.gtaxqh.com/html/2017/mrsp_0901/13121.html' for key 'PRIMARY'")
# [SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]
# [parameters: {'date': '2019-05-28', 'company': '国投安信', 'type': 'After Market', 'title': '国投安信期货每日收评\n2017-09-01', 'url': 'http://www.gtaxqh.com/html/2017/mrsp_0901/13121.html', 'Content': '当前位置：首页>研究服务>综合类晨报>每日收评\n\n国投安信期货每日收评\n\n来源： 发布时间：2017-09-01\n\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1532 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。'}]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# Problem found (pymysql.err.IntegrityError) (1062, "Duplicate entry 'http://www.gtaxqh.com/html/2017/mrsp_0905/13155.html' for key 'PRIMARY'")
# [SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]
# [parameters: {'date': '2019-05-28', 'company': '国投安信', 'type': 'After Market', 'title': '国投安信期货每日收评\n2017-09-05', 'url': 'http://www.gtaxqh.com/html/2017/mrsp_0905/13155.html', 'Content': '当前位置：首页>研究服务>综合类晨报>每日收评\n\n国投安信期货每日收评\n\n来源： 发布时间：2017-09-05\n\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1538 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。'}]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# Problem found (pymysql.err.IntegrityError) (1062, "Duplicate entry 'http://www.gtaxqh.com/html/2017/mrsp_0906/13175.html' for key 'PRIMARY'")
# [SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]
# [parameters: {'date': '2019-05-28', 'company': '国投安信', 'type': 'After Market', 'title': '国投安信期货每日收评\n2017-09-06', 'url': 'http://www.gtaxqh.com/html/2017/mrsp_0906/13175.html', 'Content': '当前位置：首页>研究服务>综合类晨报>每日收评\n\n国投安信期货每日收评\n\n来源： 发布时间：2017-09-06\n\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1304 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。'}]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# Problem found (pymysql.err.IntegrityError) (1062, "Duplicate entry 'http://www.gtaxqh.com/html/2017/mrsp_0907/13188.html' for key 'PRIMARY'")
# [SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]
# [parameters: {'date': '2019-05-28', 'company': '国投安信', 'type': 'After Market', 'title': '国投安信期货每日收评\n2017-09-07', 'url': 'http://www.gtaxqh.com/html/2017/mrsp_0907/13188.html', 'Content': '当前位置：首页>研究服务>综合类晨报>每日收评\n\n国投安信期货每日收评\n\n来源： 发布时间：2017-09-07\n\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1668 characters truncated) ... 和完整，但并不保证报告所述信息的准确性和完整性。本报告不能作为投资研究决策的依据，不能作为道义的、责任的和法律的依据或者凭证，无论是否已经明示或者暗示。国投安信期货有限公司将随时补充、更正和修订有关信息，但不保证及时发布。对于本报告所提供信息所导致的任何直接的或者间接的投资盈亏后果不承担任何责任。'}]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# Problem found (pymysql.err.IntegrityError) (1062, "Duplicate entry 'http://www.gtaxqh.com/html/2017/mrsp_0908/13205.html' for key 'PRIMARY'")
# [SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]
# [parameters: {'date': '2019-05-28', 'company': '国投安信', 'type': 'After Market', 'title': '国投安信期货每日收评\n2017-09-08', 'url': 'http://www.gtaxqh.com/html/2017/mrsp_0908/13205.html', 'Content': '当前位置：首页>研究服务>综合类晨报>每日收评\n\n国投安信期货每日收评\n\n来源： 发布时间：2017-09-08\n\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1874 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。'}]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# Problem found (pymysql.err.IntegrityError) (1062, "Duplicate entry 'http://www.gtaxqh.com/html/2017/mrsp_0912/13244.html' for key 'PRIMARY'")
# [SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]
# [parameters: {'date': '2019-05-28', 'company': '国投安信', 'type': 'After Market', 'title': '国投安信期货每日收评\n2017-09-12', 'url': 'http://www.gtaxqh.com/html/2017/mrsp_0912/13244.html', 'Content': '当前位置：首页>研究服务>综合类晨报>每日收评\n\n国投安信期货每日收评\n\n来源： 发布时间：2017-09-12\n\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1618 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。'}]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# Problem found (pymysql.err.IntegrityError) (1062, "Duplicate entry 'http://www.gtaxqh.com/html/2017/mrsp_0913/13257.html' for key 'PRIMARY'")
# [SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]
# [parameters: {'date': '2019-05-28', 'company': '国投安信', 'type': 'After Market', 'title': '国投安信期货每日收评\n2017-09-13', 'url': 'http://www.gtaxqh.com/html/2017/mrsp_0913/13257.html', 'Content': '当前位置：首页>研究服务>综合类晨报>每日收评\n\n国投安信期货每日收评\n\n来源： 发布时间：2017-09-13\n\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1417 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。'}]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# Problem found (pymysql.err.IntegrityError) (1062, "Duplicate entry 'http://www.gtaxqh.com/html/2017/mrsp_0914/13272.html' for key 'PRIMARY'")
# [SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]
# [parameters: {'date': '2019-05-28', 'company': '国投安信', 'type': 'After Market', 'title': '国投安信期货每日收评\n2017-09-14', 'url': 'http://www.gtaxqh.com/html/2017/mrsp_0914/13272.html', 'Content': '当前位置：首页>研究服务>综合类晨报>每日收评\n\n国投安信期货每日收评\n\n来源： 发布时间：2017-09-14\n\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1437 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。'}]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# Problem found (pymysql.err.IntegrityError) (1062, "Duplicate entry 'http://www.gtaxqh.com/html/2017/mrsp_0915/13285.html' for key 'PRIMARY'")
# [SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]
# [parameters: {'date': '2019-05-28', 'company': '国投安信', 'type': 'After Market', 'title': '国投安信期货每日收评\n2017-09-15', 'url': 'http://www.gtaxqh.com/html/2017/mrsp_0915/13285.html', 'Content': '当前位置：首页>研究服务>综合类晨报>每日收评\n\n国投安信期货每日收评\n\n来源： 发布时间：2017-09-15\n\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1581 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。'}]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# Problem found (pymysql.err.IntegrityError) (1062, "Duplicate entry 'http://www.gtaxqh.com/html/2017/mrsp_0915/13286.html' for key 'PRIMARY'")
# [SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]
# [parameters: {'date': '2019-05-28', 'company': '国投安信', 'type': 'After Market', 'title': '国投安信期货每日收评\n2017-09-15', 'url': 'http://www.gtaxqh.com/html/2017/mrsp_0915/13286.html', 'Content': '当前位置：首页>研究服务>综合类晨报>每日收评\n\n国投安信期货每日收评\n\n来源： 发布时间：2017-09-15\n\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1581 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。'}]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# Problem found (pymysql.err.IntegrityError) (1062, "Duplicate entry 'http://www.gtaxqh.com/html/2017/mrsp_0918/13319.html' for key 'PRIMARY'")
# [SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]
# [parameters: {'date': '2019-05-28', 'company': '国投安信', 'type': 'After Market', 'title': '国投安信期货每日收评\n2017-09-18', 'url': 'http://www.gtaxqh.com/html/2017/mrsp_0918/13319.html', 'Content': '当前位置：首页>研究服务>综合类晨报>每日收评\n\n国投安信期货每日收评\n\n来源： 发布时间：2017-09-18\n\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1723 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。'}]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# Problem found (pymysql.err.IntegrityError) (1062, "Duplicate entry 'http://www.gtaxqh.com/html/2017/mrsp_0919/13341.html' for key 'PRIMARY'")
# [SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]
# [parameters: {'date': '2019-05-28', 'company': '国投安信', 'type': 'After Market', 'title': '国投安信期货每日收评\n2017-09-19', 'url': 'http://www.gtaxqh.com/html/2017/mrsp_0919/13341.html', 'Content': '当前位置：首页>研究服务>综合类晨报>每日收评\n\n国投安信期货每日收评\n\n来源： 发布时间：2017-09-19\n\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1710 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。'}]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# Problem found (pymysql.err.IntegrityError) (1062, "Duplicate entry 'http://www.gtaxqh.com/html/2017/mrsp_0920/13358.html' for key 'PRIMARY'")
# [SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]
# [parameters: {'date': '2019-05-28', 'company': '国投安信', 'type': 'After Market', 'title': '国投安信期货每日收评\n2017-09-20', 'url': 'http://www.gtaxqh.com/html/2017/mrsp_0920/13358.html', 'Content': '当前位置：首页>研究服务>综合类晨报>每日收评\n\n国投安信期货每日收评\n\n来源： 发布时间：2017-09-20\n\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1437 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。'}]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# Problem found (pymysql.err.IntegrityError) (1062, "Duplicate entry 'http://www.gtaxqh.com/html/2017/mrsp_0921/13376.html' for key 'PRIMARY'")
# [SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]
# [parameters: {'date': '2019-05-28', 'company': '国投安信', 'type': 'After Market', 'title': '国投安信期货每日收评\n2017-09-21', 'url': 'http://www.gtaxqh.com/html/2017/mrsp_0921/13376.html', 'Content': '当前位置：首页>研究服务>综合类晨报>每日收评\n\n国投安信期货每日收评\n\n来源： 发布时间：2017-09-21\n\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 车红云 有 ... (1609 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。'}]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# Problem found (pymysql.err.IntegrityError) (1062, "Duplicate entry 'http://www.gtaxqh.com/html/2017/mrsp_0922/13396.html' for key 'PRIMARY'")
# [SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]
# [parameters: {'date': '2019-05-28', 'company': '国投安信', 'type': 'After Market', 'title': '国投安信期货每日收评\n2017-09-22', 'url': 'http://www.gtaxqh.com/html/2017/mrsp_0922/13396.html', 'Content': '当前位置：首页>研究服务>综合类晨报>每日收评\n\n国投安信期货每日收评\n\n来源： 发布时间：2017-09-22\n\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 车红云 有 ... (1114 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。'}]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# Problem found (pymysql.err.IntegrityError) (1062, "Duplicate entry 'http://www.gtaxqh.com/html/2017/mrsp_0928/13484.html' for key 'PRIMARY'")
# [SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]
# [parameters: {'date': '2019-05-28', 'company': '国投安信', 'type': 'After Market', 'title': '国投安信期货每日收评\n2017-09-28', 'url': 'http://www.gtaxqh.com/html/2017/mrsp_0928/13484.html', 'Content': '当前位置：首页>研究服务>综合类晨报>每日收评\n\n国投安信期货每日收评\n\n来源： 发布时间：2017-09-28\n\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1538 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。'}]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# Problem found (pymysql.err.IntegrityError) (1062, "Duplicate entry 'http://www.gtaxqh.com/html/2017/mrsp_1103/13869.html' for key 'PRIMARY'")
# [SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]
# [parameters: {'date': '2019-05-28', 'company': '国投安信', 'type': 'After Market', 'title': '国投安信期货每日收评\n2017-11-03', 'url': 'http://www.gtaxqh.com/html/2017/mrsp_1103/13869.html', 'Content': '当前位置：首页>研究服务>综合类晨报>每日收评\n\n国投安信期货每日收评\n\n来源： 发布时间：2017-11-03\n\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1407 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。'}]
# (Background on this error at: http://sqlalche.me/e/gkpj)
# Completed
# {'(pymysql.err.IntegrityError) (1062, "Duplicate entry \'http://www.gtaxqh.com/html/2017/mrsp_0831/13106.html\' for key \'PRIMARY\'")\n[SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]\n[parameters: {\'date\': \'2019-05-28\', \'company\': \'国投安信\', \'type\': \'After Market\', \'title\': \'国投安信期货每日收评\\n2017-08-31\', \'url\': \'http://www.gtaxqh.com/html/2017/mrsp_0831/13106.html\', \'Content\': \'当前位置：首页>研究服务>综合类晨报>每日收评\\n\\n国投安信期货每日收评\\n\\n来源： 发布时间：2017-08-31\\n\\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1233 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。\'}]\n(Background on this error at: http://sqlalche.me/e/gkpj)': [12],
#  '(pymysql.err.IntegrityError) (1062, "Duplicate entry \'http://www.gtaxqh.com/html/2017/mrsp_0901/13121.html\' for key \'PRIMARY\'")\n[SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]\n[parameters: {\'date\': \'2019-05-28\', \'company\': \'国投安信\', \'type\': \'After Market\', \'title\': \'国投安信期货每日收评\\n2017-09-01\', \'url\': \'http://www.gtaxqh.com/html/2017/mrsp_0901/13121.html\', \'Content\': \'当前位置：首页>研究服务>综合类晨报>每日收评\\n\\n国投安信期货每日收评\\n\\n来源： 发布时间：2017-09-01\\n\\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1532 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。\'}]\n(Background on this error at: http://sqlalche.me/e/gkpj)': [9],
#  '(pymysql.err.IntegrityError) (1062, "Duplicate entry \'http://www.gtaxqh.com/html/2017/mrsp_0905/13155.html\' for key \'PRIMARY\'")\n[SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]\n[parameters: {\'date\': \'2019-05-28\', \'company\': \'国投安信\', \'type\': \'After Market\', \'title\': \'国投安信期货每日收评\\n2017-09-05\', \'url\': \'http://www.gtaxqh.com/html/2017/mrsp_0905/13155.html\', \'Content\': \'当前位置：首页>研究服务>综合类晨报>每日收评\\n\\n国投安信期货每日收评\\n\\n来源： 发布时间：2017-09-05\\n\\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1538 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。\'}]\n(Background on this error at: http://sqlalche.me/e/gkpj)': [8],
#  '(pymysql.err.IntegrityError) (1062, "Duplicate entry \'http://www.gtaxqh.com/html/2017/mrsp_0906/13175.html\' for key \'PRIMARY\'")\n[SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]\n[parameters: {\'date\': \'2019-05-28\', \'company\': \'国投安信\', \'type\': \'After Market\', \'title\': \'国投安信期货每日收评\\n2017-09-06\', \'url\': \'http://www.gtaxqh.com/html/2017/mrsp_0906/13175.html\', \'Content\': \'当前位置：首页>研究服务>综合类晨报>每日收评\\n\\n国投安信期货每日收评\\n\\n来源： 发布时间：2017-09-06\\n\\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1304 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。\'}]\n(Background on this error at: http://sqlalche.me/e/gkpj)': [5],
#  '(pymysql.err.IntegrityError) (1062, "Duplicate entry \'http://www.gtaxqh.com/html/2017/mrsp_0907/13188.html\' for key \'PRIMARY\'")\n[SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]\n[parameters: {\'date\': \'2019-05-28\', \'company\': \'国投安信\', \'type\': \'After Market\', \'title\': \'国投安信期货每日收评\\n2017-09-07\', \'url\': \'http://www.gtaxqh.com/html/2017/mrsp_0907/13188.html\', \'Content\': \'当前位置：首页>研究服务>综合类晨报>每日收评\\n\\n国投安信期货每日收评\\n\\n来源： 发布时间：2017-09-07\\n\\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1668 characters truncated) ... 和完整，但并不保证报告所述信息的准确性和完整性。本报告不能作为投资研究决策的依据，不能作为道义的、责任的和法律的依据或者凭证，无论是否已经明示或者暗示。国投安信期货有限公司将随时补充、更正和修订有关信息，但不保证及时发布。对于本报告所提供信息所导致的任何直接的或者间接的投资盈亏后果不承担任何责任。\'}]\n(Background on this error at: http://sqlalche.me/e/gkpj)': [14],
#  '(pymysql.err.IntegrityError) (1062, "Duplicate entry \'http://www.gtaxqh.com/html/2017/mrsp_0908/13205.html\' for key \'PRIMARY\'")\n[SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]\n[parameters: {\'date\': \'2019-05-28\', \'company\': \'国投安信\', \'type\': \'After Market\', \'title\': \'国投安信期货每日收评\\n2017-09-08\', \'url\': \'http://www.gtaxqh.com/html/2017/mrsp_0908/13205.html\', \'Content\': \'当前位置：首页>研究服务>综合类晨报>每日收评\\n\\n国投安信期货每日收评\\n\\n来源： 发布时间：2017-09-08\\n\\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1874 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。\'}]\n(Background on this error at: http://sqlalche.me/e/gkpj)': [6],
#  '(pymysql.err.IntegrityError) (1062, "Duplicate entry \'http://www.gtaxqh.com/html/2017/mrsp_0912/13244.html\' for key \'PRIMARY\'")\n[SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]\n[parameters: {\'date\': \'2019-05-28\', \'company\': \'国投安信\', \'type\': \'After Market\', \'title\': \'国投安信期货每日收评\\n2017-09-12\', \'url\': \'http://www.gtaxqh.com/html/2017/mrsp_0912/13244.html\', \'Content\': \'当前位置：首页>研究服务>综合类晨报>每日收评\\n\\n国投安信期货每日收评\\n\\n来源： 发布时间：2017-09-12\\n\\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1618 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。\'}]\n(Background on this error at: http://sqlalche.me/e/gkpj)': [3],
#  '(pymysql.err.IntegrityError) (1062, "Duplicate entry \'http://www.gtaxqh.com/html/2017/mrsp_0913/13257.html\' for key \'PRIMARY\'")\n[SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]\n[parameters: {\'date\': \'2019-05-28\', \'company\': \'国投安信\', \'type\': \'After Market\', \'title\': \'国投安信期货每日收评\\n2017-09-13\', \'url\': \'http://www.gtaxqh.com/html/2017/mrsp_0913/13257.html\', \'Content\': \'当前位置：首页>研究服务>综合类晨报>每日收评\\n\\n国投安信期货每日收评\\n\\n来源： 发布时间：2017-09-13\\n\\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1417 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。\'}]\n(Background on this error at: http://sqlalche.me/e/gkpj)': [2],
#  '(pymysql.err.IntegrityError) (1062, "Duplicate entry \'http://www.gtaxqh.com/html/2017/mrsp_0914/13272.html\' for key \'PRIMARY\'")\n[SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]\n[parameters: {\'date\': \'2019-05-28\', \'company\': \'国投安信\', \'type\': \'After Market\', \'title\': \'国投安信期货每日收评\\n2017-09-14\', \'url\': \'http://www.gtaxqh.com/html/2017/mrsp_0914/13272.html\', \'Content\': \'当前位置：首页>研究服务>综合类晨报>每日收评\\n\\n国投安信期货每日收评\\n\\n来源： 发布时间：2017-09-14\\n\\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1437 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。\'}]\n(Background on this error at: http://sqlalche.me/e/gkpj)': [4],
#  '(pymysql.err.IntegrityError) (1062, "Duplicate entry \'http://www.gtaxqh.com/html/2017/mrsp_0915/13285.html\' for key \'PRIMARY\'")\n[SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]\n[parameters: {\'date\': \'2019-05-28\', \'company\': \'国投安信\', \'type\': \'After Market\', \'title\': \'国投安信期货每日收评\\n2017-09-15\', \'url\': \'http://www.gtaxqh.com/html/2017/mrsp_0915/13285.html\', \'Content\': \'当前位置：首页>研究服务>综合类晨报>每日收评\\n\\n国投安信期货每日收评\\n\\n来源： 发布时间：2017-09-15\\n\\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1581 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。\'}]\n(Background on this error at: http://sqlalche.me/e/gkpj)': [13],
#  '(pymysql.err.IntegrityError) (1062, "Duplicate entry \'http://www.gtaxqh.com/html/2017/mrsp_0915/13286.html\' for key \'PRIMARY\'")\n[SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]\n[parameters: {\'date\': \'2019-05-28\', \'company\': \'国投安信\', \'type\': \'After Market\', \'title\': \'国投安信期货每日收评\\n2017-09-15\', \'url\': \'http://www.gtaxqh.com/html/2017/mrsp_0915/13286.html\', \'Content\': \'当前位置：首页>研究服务>综合类晨报>每日收评\\n\\n国投安信期货每日收评\\n\\n来源： 发布时间：2017-09-15\\n\\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1581 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。\'}]\n(Background on this error at: http://sqlalche.me/e/gkpj)': [1],
#  '(pymysql.err.IntegrityError) (1062, "Duplicate entry \'http://www.gtaxqh.com/html/2017/mrsp_0918/13319.html\' for key \'PRIMARY\'")\n[SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]\n[parameters: {\'date\': \'2019-05-28\', \'company\': \'国投安信\', \'type\': \'After Market\', \'title\': \'国投安信期货每日收评\\n2017-09-18\', \'url\': \'http://www.gtaxqh.com/html/2017/mrsp_0918/13319.html\', \'Content\': \'当前位置：首页>研究服务>综合类晨报>每日收评\\n\\n国投安信期货每日收评\\n\\n来源： 发布时间：2017-09-18\\n\\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1723 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。\'}]\n(Background on this error at: http://sqlalche.me/e/gkpj)': [10],
#  '(pymysql.err.IntegrityError) (1062, "Duplicate entry \'http://www.gtaxqh.com/html/2017/mrsp_0919/13341.html\' for key \'PRIMARY\'")\n[SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]\n[parameters: {\'date\': \'2019-05-28\', \'company\': \'国投安信\', \'type\': \'After Market\', \'title\': \'国投安信期货每日收评\\n2017-09-19\', \'url\': \'http://www.gtaxqh.com/html/2017/mrsp_0919/13341.html\', \'Content\': \'当前位置：首页>研究服务>综合类晨报>每日收评\\n\\n国投安信期货每日收评\\n\\n来源： 发布时间：2017-09-19\\n\\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1710 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。\'}]\n(Background on this error at: http://sqlalche.me/e/gkpj)': [7],
#  '(pymysql.err.IntegrityError) (1062, "Duplicate entry \'http://www.gtaxqh.com/html/2017/mrsp_0920/13358.html\' for key \'PRIMARY\'")\n[SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]\n[parameters: {\'date\': \'2019-05-28\', \'company\': \'国投安信\', \'type\': \'After Market\', \'title\': \'国投安信期货每日收评\\n2017-09-20\', \'url\': \'http://www.gtaxqh.com/html/2017/mrsp_0920/13358.html\', \'Content\': \'当前位置：首页>研究服务>综合类晨报>每日收评\\n\\n国投安信期货每日收评\\n\\n来源： 发布时间：2017-09-20\\n\\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1437 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。\'}]\n(Background on this error at: http://sqlalche.me/e/gkpj)': [11],
#  '(pymysql.err.IntegrityError) (1062, "Duplicate entry \'http://www.gtaxqh.com/html/2017/mrsp_0921/13376.html\' for key \'PRIMARY\'")\n[SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]\n[parameters: {\'date\': \'2019-05-28\', \'company\': \'国投安信\', \'type\': \'After Market\', \'title\': \'国投安信期货每日收评\\n2017-09-21\', \'url\': \'http://www.gtaxqh.com/html/2017/mrsp_0921/13376.html\', \'Content\': \'当前位置：首页>研究服务>综合类晨报>每日收评\\n\\n国投安信期货每日收评\\n\\n来源： 发布时间：2017-09-21\\n\\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 车红云 有 ... (1609 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。\'}]\n(Background on this error at: http://sqlalche.me/e/gkpj)': [16],
#  '(pymysql.err.IntegrityError) (1062, "Duplicate entry \'http://www.gtaxqh.com/html/2017/mrsp_0922/13396.html\' for key \'PRIMARY\'")\n[SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]\n[parameters: {\'date\': \'2019-05-28\', \'company\': \'国投安信\', \'type\': \'After Market\', \'title\': \'国投安信期货每日收评\\n2017-09-22\', \'url\': \'http://www.gtaxqh.com/html/2017/mrsp_0922/13396.html\', \'Content\': \'当前位置：首页>研究服务>综合类晨报>每日收评\\n\\n国投安信期货每日收评\\n\\n来源： 发布时间：2017-09-22\\n\\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 车红云 有 ... (1114 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。\'}]\n(Background on this error at: http://sqlalche.me/e/gkpj)': [15],
#  '(pymysql.err.IntegrityError) (1062, "Duplicate entry \'http://www.gtaxqh.com/html/2017/mrsp_0928/13484.html\' for key \'PRIMARY\'")\n[SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]\n[parameters: {\'date\': \'2019-05-28\', \'company\': \'国投安信\', \'type\': \'After Market\', \'title\': \'国投安信期货每日收评\\n2017-09-28\', \'url\': \'http://www.gtaxqh.com/html/2017/mrsp_0928/13484.html\', \'Content\': \'当前位置：首页>研究服务>综合类晨报>每日收评\\n\\n国投安信期货每日收评\\n\\n来源： 发布时间：2017-09-28\\n\\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1538 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。\'}]\n(Background on this error at: http://sqlalche.me/e/gkpj)': [18],
#  '(pymysql.err.IntegrityError) (1062, "Duplicate entry \'http://www.gtaxqh.com/html/2017/mrsp_1103/13869.html\' for key \'PRIMARY\'")\n[SQL: INSERT INTO content (date, company, type, title, url, `Content`) VALUES (%(date)s, %(company)s, %(type)s, %(title)s, %(url)s, %(Content)s)]\n[parameters: {\'date\': \'2019-05-28\', \'company\': \'国投安信\', \'type\': \'After Market\', \'title\': \'国投安信期货每日收评\\n2017-11-03\', \'url\': \'http://www.gtaxqh.com/html/2017/mrsp_1103/13869.html\', \'Content\': \'当前位置：首页>研究服务>综合类晨报>每日收评\\n\\n国投安信期货每日收评\\n\\n来源： 发布时间：2017-11-03\\n\\n序号 研究员姓名 研究方向 从业资格号 投资咨询号 1 曹颖 煤焦钢矿 F3003925 Z0012043 2 何建辉 F0242190 Z0000586 3 高明宇 动 ... (1407 characters truncated) ... 直接的或者间接的投资盈亏后果不承担任何责任。本报告版权仅为国投安信期货有限公司所有，未经书面许可，任何机构和个人不得以任何形式翻版、复制和发布。如引用发布，需注明出处为国投安信期货有限公司，且不得对本报告进行有悖原意的引用、删节和修改。国投安信期货有限公司对于本免责申明条款具有修改权和最终解释权。\'}]\n(Background on this error at: http://sqlalche.me/e/gkpj)': [17]}
