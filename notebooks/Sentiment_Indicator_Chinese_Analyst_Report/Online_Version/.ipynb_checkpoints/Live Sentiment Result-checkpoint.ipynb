# %% [markdown]
# # Objective
# This notebook aims to check the predictive value of live sentiment score (Get by analyzing the analyst report)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
import seaborn as sns
from scipy.stats import norm
import sqlalchemy as sq

# %% [markdown]
# # Read The LME Spot Price Data

# %%
metal = '/home/liangchen/4e/Financial Data/LMCADY'
price = pd.read_csv(metal+'.csv')
price['Index'] =  pd.to_datetime(price['Index'])
price['return_1d'] = (price['LMCADY']/price['LMCADY'].shift(1)-1)*100
price.dropna(inplace = True)

# %% [markdown]
# # Create return over several time horizon

# %%
price['return_1d'] = ((price['LMCADY'] / price['LMCADY'].shift(1)) -1)*100
price['return_3d'] = ((price['LMCADY'] / price['LMCADY'].shift(3)) -1)*100
price['return_5d'] = ((price['LMCADY'] / price['LMCADY'].shift(5)) -1)*100
price['return_7d'] = ((price['LMCADY'] / price['LMCADY'].shift(7)) -1)*100
price['return_10d'] = ((price['LMCADY'] / price['LMCADY'].shift(10)) -1)*100
price['return_15d'] = ((price['LMCADY'] / price['LMCADY'].shift(15)) -1)*100
price['return_20d'] = ((price['LMCADY'] / price['LMCADY'].shift(20)) -1)*100

# %%
period = 100
price['Std1d_20'] = (price[u'return_1d'].shift(1).rolling(period).std())
price['Std3d_20'] = (price[u'return_3d'].shift(1).rolling(period).std())
price['Std5d_20'] = (price[u'return_5d'].shift(1).rolling(period).std())
price['Std7d_20'] = (price[u'return_7d'].shift(1).rolling(period).std())
price['Std10d_20'] = (price[u'return_10d'].shift(1).rolling(period).std())
price['Std15d_20'] = (price[u'return_15d'].shift(1).rolling(period).std())
price['Std20d_20'] = (price[u'return_20d'].shift(1).rolling(period).std())

# %%
price_forward = price.copy()
price_forward['return_1d'] = price_forward['return_1d'].shift(-1)
price_forward['return_3d'] = price_forward['return_3d'].shift(-3)
price_forward['return_5d'] = price_forward['return_5d'].shift(-5)
price_forward['return_7d'] = price_forward['return_7d'].shift(-7)
price_forward['return_10d'] = price_forward['return_10d'].shift(-10)
price_forward['return_15d'] = price_forward['return_15d'].shift(-15)
price_forward['return_20d'] = price_forward['return_20d'].shift(-20)

# %% [markdown]
# # Data Preprocessing

# %%
# Input: target is a float value we wish to categorize, num_tier is int which indicates 
# the number of classes we wish to classified, tier_lst is a list of cdf probability (sorted ascendingly) for us to have a range to classify
# different classes, mean is the distirbution mean, std is the distribtion std

# Result: This function will return a classified value 

def discrete(target,num_tier,tier_lst,mean,std):
    if num_tier-1 != len(tier_lst):
        print ('num_tier does not match tier_lst')
        return
    
    tier_point =[]
    for i in tier_lst:
        tier_point.append(norm.ppf(i, loc=mean, scale=std))
    
    decided = 0
    
    for i in range(num_tier-1):
        if target<=tier_point[i]:
            decided = 1
            break
    if decided ==0:
        return num_tier-1
    else:
        return i

# %%
def give_sign (data):
    if data>0:
        return 1
    elif data<0:
        return -1
    else:
        return 0

# %% [markdown]
# # Discrete Price

# %%
target = 'return_1d'
output_name = 'discrete_1d'
mean = 0
std = 'Std1d_20'
tier = 5
tier_lst = [0.159,0.359,0.661,0.841]
price_forward[output_name] = price_forward.apply(lambda x: discrete(x[target],tier,tier_lst,mean,x[std]),axis=1)-2
price_forward[output_name] = price_forward[output_name].apply(give_sign)

# %%
target = 'return_3d'
output_name = 'discrete_3d'
mean = 0
std = 'Std3d_20'
tier = 5
tier_lst = [0.159,0.353,0.661,0.841]
price_forward[output_name] = price_forward.apply(lambda x: discrete(x[target],tier,tier_lst,mean,x[std]),axis=1)-2
price_forward[output_name] = price_forward[output_name].apply(give_sign)

# %%
target = 'return_5d'
output_name = 'discrete_5d'
mean = 0
std = 'Std5d_20'
tier = 5
tier_lst = [0.159,0.329,0.661,0.841]
price_forward[output_name] = price_forward.apply(lambda x: discrete(x[target],tier,tier_lst,mean,x[std]),axis=1)-2
price_forward[output_name] = price_forward[output_name].apply(give_sign)

# %%
target = 'return_7d'
output_name = 'discrete_7d'
mean = 0
std = 'Std7d_20'
tier = 5
tier_lst = [0.159,0.327,0.663,0.841]
price_forward[output_name] = price_forward.apply(lambda x: discrete(x[target],tier,tier_lst,mean,x[std]),axis=1)-2
price_forward[output_name] = price_forward[output_name].apply(give_sign)

# %%
target = 'return_10d'
output_name = 'discrete_10d'
mean = 0
std = 'Std10d_20'
tier = 5
tier_lst = [0.159,0.329,0.661,0.841]
price_forward[output_name] = price_forward.apply(lambda x: discrete(x[target],tier,tier_lst,mean,x[std]),axis=1)-2
price_forward[output_name] = price_forward[output_name].apply(give_sign)

# %%
target = 'return_15d'
output_name = 'discrete_15d'
mean = 0
std = 'Std15d_20'
tier = 5
tier_lst = [0.159,0.289,0.681,0.841]
price_forward[output_name] = price_forward.apply(lambda x: discrete(x[target],tier,tier_lst,mean,x[std]),axis=1)-2
price_forward[output_name] = price_forward[output_name].apply(give_sign)

# %%
target = 'return_20d'
output_name = 'discrete_20d'
mean = 0
std = 'Std20d_20'
tier = 5
tier_lst = [0.159,0.279,0.671,0.841]
price_forward[output_name] = price_forward.apply(lambda x: discrete(x[target],tier,tier_lst,mean,x[std]),axis=1)-2
price_forward[output_name] = price_forward[output_name].apply(give_sign)

# %% [markdown]
# # Simple price prediction using indicator

# %% [markdown]
# Define a function to give positive sign to data point bigger than zero and negative sign to data point smaller than zero

# %%
# Input: data is the total dataframe, result is the col name of the target return and indicator is the col name of the predictive score
# Obj: This fucntion will give us a the result of the simple prediction strategy

def prediction(result,data,indicator):
    indi_1 = data[indicator]
    sign_indi1 = indi_1.apply(give_sign) 
    sign_return = data[result].apply(give_sign)
    same_result_1= (sign_return == sign_indi1)
    reverse_result_1 = (sign_indi1 == -1 *sign_return)
    
    for i in sign_return.value_counts().index:
        print('Number of ' + str(i) + ' in '+ result+ " : "+str(round(sign_return.value_counts()[i]/float(len(sign_return)),6)))
    
    print('Accuracy for following the same sign of Indicator 1 ' + result+ " : "+str(round(same_result_1.value_counts()[True]/float(len(sign_return)),6)))
    print('Accuracy for following the reverse sign of Indicator 1 '+ result+ " : "+str(round(reverse_result_1.value_counts()[True]/float(len(sign_return)),6)))

# %% [markdown]
# # Discrete score and make prediction

# %%
# Input: data is the total dataframe, target is the col name of target return, indicator is the col name of indicator

# Result: This function will return a confusion metric 

def draw_confusion(data,target,indicator):
    indi_1 = data[indicator]
    sign_indi1 = indi_1.apply(give_sign) 
    sign_return = data[target].apply(give_sign)
    result = []
    for i in [-1,0,1]:
        row = []
        for j in [-1,0,1]:
            num = (sign_return==i) & (sign_indi1 ==j)
            row.append(num.value_counts()[True])
        result.append(row)
    
    plt.figure(figsize=(9,9))
    sns.heatmap(result, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
    plt.ylabel(target);
    plt.xlabel('Score');
    plt.title('Confusion metric for Score vs ' + target, size = 15);
    return result

# %% [markdown]
# ## Classify our score data and return

# %%
engine = sq.create_engine("mysql+pymysql://root:next++4e@localhost/Alternative_DB?host=localhost?port=3306")
conn = engine.connect()
day = '1d'
db_result = pd.read_sql("Select * From score where horizon = 1",conn)
conn.close()

price_indicator_forward = db_result.merge(price_forward,left_on='date',right_on='Index',how='inner')

# Price Predicition
target = 'return_'+day
output_name = 'discrete_'+day
mean = 0
std = 'Std'+day+'_20'
tier = 5
tier_lst = [0.159,0.359,0.661,0.841]
price_indicator_forward[output_name] = price_indicator_forward.apply(lambda x: discrete(x[target],tier,tier_lst,mean,x[std]),axis=1)-2
prediction(output_name,price_indicator_forward,'discrete_score')
result = draw_confusion(price_indicator_forward,output_name,'discrete_score')
print(norm.ppf(tier_lst, loc=mean, scale=price_indicator_forward[std].iloc[-1]))
# Out:
# Number of 0 in discrete_1d : 0.341463
# Number of 1 in discrete_1d : 0.329268
# Number of -1 in discrete_1d : 0.329268
# Accuracy for following the same sign of Indicator 1 discrete_1d : 0.301829
# Accuracy for following the reverse sign of Indicator 1 discrete_1d : 0.378049
# [-1.15099525 -0.41625504  0.4785675   1.15099525]

# %%
engine = sq.create_engine("mysql+pymysql://root:next++4e@localhost/Alternative_DB?host=localhost?port=3306")
conn = engine.connect()
day = '3d'
db_result = pd.read_sql("Select * From score where horizon = 3",conn)
conn.close()

price_indicator_forward = db_result.merge(price_forward,left_on='date',right_on='Index',how='inner')

# Price Predicition
target = 'return_'+day
output_name = 'discrete_'+day
mean = 0
std = 'Std'+day+'_20'
tier = 5
tier_lst =  [0.159,0.353,0.661,0.841]
price_indicator_forward[output_name] = price_indicator_forward.apply(lambda x: discrete(x[target],tier,tier_lst,mean,x[std]),axis=1)-2
prediction(output_name,price_indicator_forward,'discrete_score')
result = draw_confusion(price_indicator_forward,output_name,'discrete_score')
print(norm.ppf(tier_lst, loc=mean, scale=price_indicator_forward[std].iloc[-1]))
# Out:
# Number of -1 in discrete_3d : 0.341463
# Number of 1 in discrete_3d : 0.332317
# Number of 0 in discrete_3d : 0.32622
# Accuracy for following the same sign of Indicator 1 discrete_3d : 0.39939
# Accuracy for following the reverse sign of Indicator 1 discrete_3d : 0.317073
# [-2.39082939 -0.90318711  0.99407295  2.39082939]

# %%
engine = sq.create_engine("mysql+pymysql://root:next++4e@localhost/Alternative_DB?host=localhost?port=3306")
conn = engine.connect()
day = '5d'
db_result = pd.read_sql("Select * From score where horizon = 7",conn)
conn.close()

price_indicator_forward = db_result.merge(price_forward,left_on='date',right_on='Index',how='inner')

# Price Predicition
target = 'return_'+day
output_name = 'discrete_'+day
mean = 0
std = 'Std'+day+'_20'
tier = 5
tier_lst = [0.159,0.329,0.661,0.841]
price_indicator_forward[output_name] = price_indicator_forward.apply(lambda x: discrete(x[target],tier,tier_lst,mean,x[std]),axis=1)-2
prediction(output_name,price_indicator_forward,'discrete_score')
result = draw_confusion(price_indicator_forward,output_name,'discrete_score')
print(norm.ppf(tier_lst, loc=mean, scale=price_indicator_forward[std].iloc[-1]))
# Out:
# Number of 0 in discrete_5d : 0.341463
# Number of 1 in discrete_5d : 0.329268
# Number of -1 in discrete_5d : 0.329268
# Accuracy for following the same sign of Indicator 1 discrete_5d : 0.384146
# Accuracy for following the reverse sign of Indicator 1 discrete_5d : 0.253049
# [-3.23760149 -1.43525236  1.34614878  3.23760149]

# %%
engine = sq.create_engine("mysql+pymysql://root:next++4e@localhost/Alternative_DB?host=localhost?port=3306")
conn = engine.connect()
day = '7d'
db_result = pd.read_sql("Select * From score where horizon = 7",conn)
conn.close()

price_indicator_forward = db_result.merge(price_forward,left_on='date',right_on='Index',how='inner')

# Price Predicition
target = 'return_'+day
output_name = 'discrete_'+day
mean = 0
std = 'Std'+day+'_20'
tier = 5
tier_lst = [0.159,0.327,0.663,0.841]
price_indicator_forward[output_name] = price_indicator_forward.apply(lambda x: discrete(x[target],tier,tier_lst,mean,x[std]),axis=1)-2
prediction(output_name,price_indicator_forward,'discrete_score')
result = draw_confusion(price_indicator_forward,output_name,'discrete_score')
print(norm.ppf(tier_lst, loc=mean, scale=price_indicator_forward[std].iloc[-1]))
# Out:
# Number of -1 in discrete_7d : 0.338415
# Number of 0 in discrete_7d : 0.332317
# Number of 1 in discrete_7d : 0.329268
# Accuracy for following the same sign of Indicator 1 discrete_7d : 0.387195
# Accuracy for following the reverse sign of Indicator 1 discrete_7d : 0.259146
# [-3.88124207 -1.74210064  1.63502906  3.88124207]

# %%
engine = sq.create_engine("mysql+pymysql://root:next++4e@localhost/Alternative_DB?host=localhost?port=3306")
conn = engine.connect()
day = '10d'
db_result = pd.read_sql("Select * From score where horizon = 10",conn)
conn.close()

price_indicator_forward = db_result.merge(price_forward,left_on='date',right_on='Index',how='inner')

# Price Predicition
target = 'return_'+day
output_name = 'discrete_'+day
mean = 0
std = 'Std'+day+'_20'
tier = 5
tier_lst = [0.159,0.329,0.661,0.841]
price_indicator_forward[output_name] = price_indicator_forward.apply(lambda x: discrete(x[target],tier,tier_lst,mean,x[std]),axis=1)-2
prediction(output_name,price_indicator_forward,'discrete_score')
result = draw_confusion(price_indicator_forward,output_name,'discrete_score')
print(norm.ppf(tier_lst, loc=mean, scale=price_indicator_forward[std].iloc[-1]))
# Out:
# Number of 0 in discrete_10d : 0.359756
# Number of 1 in discrete_10d : 0.332317
# Number of -1 in discrete_10d : 0.307927
# Accuracy for following the same sign of Indicator 1 discrete_10d : 0.39939
# Accuracy for following the reverse sign of Indicator 1 discrete_10d : 0.268293
# [-4.78965072 -2.1232871   1.99146884  4.78965072]

# %%
engine = sq.create_engine("mysql+pymysql://root:next++4e@localhost/Alternative_DB?host=localhost?port=3306")
conn = engine.connect()
day = '15d'
db_result = pd.read_sql("Select * From score where horizon = 15",conn)
conn.close()

price_indicator_forward = db_result.merge(price_forward,left_on='date',right_on='Index',how='inner')

# Price Predicition
target = 'return_'+day
output_name = 'discrete_'+day
mean = 0
std = 'Std'+day+'_20'
tier = 5
tier_lst = [0.159,0.289,0.681,0.841]
price_indicator_forward[output_name] = price_indicator_forward.apply(lambda x: discrete(x[target],tier,tier_lst,mean,x[std]),axis=1)-2
prediction(output_name,price_indicator_forward,'discrete_score')
result = draw_confusion(price_indicator_forward,output_name,'discrete_score')
print(norm.ppf(tier_lst, loc=mean, scale=price_indicator_forward[std].iloc[-1]))
# Out:
# Number of 0 in discrete_15d : 0.347561
# Number of 1 in discrete_15d : 0.341463
# Number of -1 in discrete_15d : 0.310976
# Accuracy for following the same sign of Indicator 1 discrete_15d : 0.39939
# Accuracy for following the reverse sign of Indicator 1 discrete_15d : 0.259146
# [-6.6750394  -3.71867532  3.14506352  6.6750394 ]

# %%
engine = sq.create_engine("mysql+pymysql://root:next++4e@localhost/Alternative_DB?host=localhost?port=3306")
conn = engine.connect()
day = '20d'
db_result = pd.read_sql("Select * From score where horizon = 20",conn)
conn.close()

price_indicator_forward = db_result.merge(price_forward,left_on='date',right_on='Index',how='inner')

# Price Predicition
target = 'return_'+day
output_name = 'discrete_'+day
mean = 0
std = 'Std'+day+'_20'
tier = 5
tier_lst =[0.159,0.279,0.671,0.841]
price_indicator_forward[output_name] = price_indicator_forward.apply(lambda x: discrete(x[target],tier,tier_lst,mean,x[std]),axis=1)-2
prediction(output_name,price_indicator_forward,'discrete_score')
result = draw_confusion(price_indicator_forward,output_name,'discrete_score')
print(norm.ppf(tier_lst, loc=mean, scale=price_indicator_forward[std].iloc[-1]))
# Out:
# Number of 1 in discrete_20d : 0.355828
# Number of -1 in discrete_20d : 0.322086
# Number of 0 in discrete_20d : 0.322086
# Accuracy for following the same sign of Indicator 1 discrete_20d : 0.45092
# Accuracy for following the reverse sign of Indicator 1 discrete_20d : 0.285276
# [-7.5306966  -4.41788313  3.33841273  7.5306966 ]
